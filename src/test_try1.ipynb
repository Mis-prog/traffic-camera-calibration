# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
video_path = '../data/Перекресток Карла Маркса.mp4'
output_frame_path = "frame.jpg"

# %%
video = cv2.VideoCapture(video_path)
frame_number = 100
video.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
# Out:
# True

# %%
success, frame = video.read()

# %%
cv2.imwrite(output_frame_path, frame)
# Out:
# True

# %%
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(frame_rgb)
plt.axis('off')  # Отключаем оси
# Out:
# (np.float64(-0.5), np.float64(1227.5), np.float64(689.5), np.float64(-0.5))

# %%
frame.shape
# Out:
# (690, 1228, 3)

# %%
video.release()

# %%
frame_rgb
# Out:
# array([[[ 77, 108, 151],
#         [ 77, 108, 151],
#         [ 77, 108, 151],
#         ...,
#         [ 37,  41,  45],
#         [ 34,  38,  42],
#         [ 37,  41,  45]],
#
#        [[ 77, 108, 151],
#         [ 77, 108, 151],
#         [ 77, 108, 151],
#         ...,
#         [ 37,  41,  45],
#         [ 35,  39,  43],
#         [ 40,  44,  48]],
#
#        [[ 77, 108, 151],
#         [ 77, 108, 151],
#         [ 77, 108, 151],
#         ...,
#         [ 41,  45,  49],
#         [ 32,  36,  40],
#         [ 34,  38,  42]],
#
#        ...,
#
#        [[ 50,  54,  69],
#         [ 50,  54,  69],
#         [ 50,  54,  69],
#         ...,
#         [ 87,  90,  97],
#         [ 85,  88,  95],
#         [ 78,  81,  88]],
#
#        [[ 45,  54,  67],
#         [ 45,  54,  67],
#         [ 47,  56,  69],
#         ...,
#         [ 81,  84,  91],
#         [ 76,  79,  86],
#         [ 72,  75,  82]],
#
#        [[ 45,  54,  67],
#         [ 45,  54,  67],
#         [ 47,  56,  69],
#         ...,
#         [ 77,  80,  87],
#         [ 71,  74,  81],
#         [ 70,  73,  80]]], dtype=uint8)

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine_distance(lat1, lon1, lat2, lon2):
    # Радиус Земли в километрах
    R = 6371000.0 
    
    # Перевод координат в радианы
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    
    # Разницы широт и долгот
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # Формула Харверсина
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    
    # Расстояние
    distance = R * c
    
    return distance

# Пример использования
lat1, lon1 = 54.725223, 55.940823 # Точка перекрекстка 
lat2, lon2 = 54.725282, 55.940433  # Точка перекрекстка
print(f"Расстояние: {haversine_distance(lat1, lon1, lat2, lon2):.2f} м")
# Out:
# Расстояние: 25.89 м
